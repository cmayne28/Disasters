# %%
#importing dependencies
import pandas as pd

# %%
#importing csv file and creating a pandas dataframe 
earthquake_file = '../Disasters/earthquakes.csv'
earthquake_df = pd.read_csv(earthquake_file)

#overview of created dataframe
earthquake_df.head()
# Out:
#     I_D FLAG_TSUNAMI  YEAR  MONTH   DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  \
# 0  9925          Tsu  1900    1.0  10.0   NaN     NaN    NaN          NaN
# 1  2566          NaN  1900    1.0  11.0   9.0     7.0                 NaN
# 2  2567          NaN  1900    1.0  14.0   NaN     NaN    NaN          NaN
# 3  2569          NaN  1900    1.0  20.0   6.0    33.0     30         10.0
# 4  2571          NaN  1900    5.0  16.0  20.0    12.0                60.0
#
#    EQ_PRIMARY               ...                 TOTAL_MISSING  \
# 0         NaN               ...                           NaN
# 1         7.8               ...                           NaN
# 2         NaN               ...                           NaN
# 3         7.4               ...                           NaN
# 4         7.8               ...                           NaN
#
#    TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  TOTAL_INJURIES_DESCRIPTION  \
# 0                        NaN             NaN                         NaN
# 1                        NaN             NaN                         NaN
# 2                        NaN             NaN                         NaN
# 3                        NaN             NaN                         NaN
# 4                        NaN             NaN                         NaN
#
#    TOTAL_DAMAGE_MILLIONS_DOLLARS  TOTAL_DAMAGE_DESCRIPTION  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       2.0
# 3                            NaN                       1.0
# 4                            NaN                       NaN
#
#    TOTAL_HOUSES_DESTROYED TOTAL_HOUSES_DESTROYED_DESCRIPTION  \
# 0                     NaN                                NaN
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
#
#   TOTAL_HOUSES_DAMAGED TOTAL_HOUSES_DAMAGED_DESCRIPTION
# 0                  NaN                              NaN
# 1                  NaN                              NaN
# 2                  NaN                              3.0
# 3                  NaN                              NaN
# 4                  NaN                              NaN
#
# [5 rows x 47 columns]

# %%
#info function to list out all the columns for visability 
earthquake_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3603 entries, 0 to 3602
# Data columns (total 47 columns):
# I_D                                   3603 non-null int64
# FLAG_TSUNAMI                          998 non-null object
# YEAR                                  3603 non-null int64
# MONTH                                 3596 non-null float64
# DAY                                   3591 non-null float64
# HOUR                                  3410 non-null float64
# MINUTE                                3381 non-null float64
# SECOND                                3341 non-null object
# FOCAL_DEPTH                           2884 non-null float64
# EQ_PRIMARY                            3296 non-null float64
# EQ_MAG_MW                             1184 non-null float64
# EQ_MAG_MS                             2198 non-null float64
# EQ_MAG_MB                             1783 non-null float64
# EQ_MAG_ML                             159 non-null float64
# EQ_MAG_MFA                            2 non-null float64
# EQ_MAG_UNK                            543 non-null float64
# INTENSITY                             1380 non-null float64
# COUNTRY                               3603 non-null object
# STATE                                 213 non-null object
# LOCATION_NAME                         3603 non-null object
# LATITUDE                              3596 non-null object
# LONGITUDE                             3596 non-null float64
# REGION_CODE                           3602 non-null float64
# DEATHS                                1395 non-null float64
# DEATHS_DESCRIPTION                    1492 non-null float64
# MISSING                               19 non-null float64
# MISSING_DESCRIPTION                   18 non-null float64
# INJURIES                              1099 non-null float64
# INJURIES_DESCRIPTION                  1249 non-null float64
# DAMAGE_MILLIONS_DOLLARS               464 non-null float64
# DAMAGE_DESCRIPTION                    2620 non-null float64
# HOUSES_DESTROYED                      601 non-null float64
# HOUSES_DESTROYED_DESCRIPTION          1028 non-null float64
# HOUSES_DAMAGED                        400 non-null float64
# HOUSES_DAMAGED_DESCRIPTION            705 non-null float64
# TOTAL_DEATHS                          1162 non-null float64
# TOTAL_DEATHS_DESCRIPTION              1231 non-null float64
# TOTAL_MISSING                         23 non-null float64
# TOTAL_MISSING_DESCRIPTION             21 non-null float64
# TOTAL_INJURIES                        1111 non-null float64
# TOTAL_INJURIES_DESCRIPTION            1253 non-null float64
# TOTAL_DAMAGE_MILLIONS_DOLLARS         411 non-null float64
# TOTAL_DAMAGE_DESCRIPTION              2148 non-null float64
# TOTAL_HOUSES_DESTROYED                614 non-null float64
# TOTAL_HOUSES_DESTROYED_DESCRIPTION    1054 non-null float64
# TOTAL_HOUSES_DAMAGED                  355 non-null float64
# TOTAL_HOUSES_DAMAGED_DESCRIPTION      630 non-null float64
# dtypes: float64(39), int64(2), object(6)
# memory usage: 1.3+ MB

# %%
#top 10 countries with most earthquakes 
earthquake_count_country = earthquake_df['COUNTRY'].value_counts()
earthquake_count_country.head(10)
# Out:
# CHINA          347
# INDONESIA      276
# JAPAN          238
# IRAN           213
# USA            185
# TURKEY         164
# ITALY          132
# PHILIPPINES    120
# RUSSIA         118
# PERU           115
# Name: COUNTRY, dtype: int64

# %%
#top 10 years with most earthquakes 
earthquake_count_year = earthquake_df['YEAR'].value_counts()
earthquake_count_year.head(15)
# Out:
# 2004    78
# 2008    77
# 2003    72
# 2007    67
# 2010    62
# 2006    61
# 2002    60
# 2009    60
# 2005    60
# 2011    59
# 2014    55
# 2017    53
# 2018    52
# 2013    52
# 1990    51
# Name: YEAR, dtype: int64

# %%
#top 5 months for most earthquakes 
earthquake_count_month = earthquake_df['MONTH'].value_counts()
earthquake_count_month.head(5)
# Out:
# 11.0    328
# 8.0     320
# 1.0     311
# 5.0     309
# 4.0     308
# Name: MONTH, dtype: int64

# %%
#top 10 earthquakes by magnitude 
earthquake_count_EQ = earthquake_df['EQ_PRIMARY'].value_counts()
earthquake_top = earthquake_df.sort_values(by='EQ_PRIMARY',ascending=False)
earthquake_top.head(10)
# Out:
#        I_D FLAG_TSUNAMI  YEAR  MONTH   DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  \
# 1311  4227          Tsu  1960    5.0  22.0  19.0    11.0     17         33.0
# 1423  4311          Tsu  1964    3.0  28.0   3.0    36.0                33.0
# 3201  9799          Tsu  2011    3.0  11.0   5.0    46.0   24.1         30.0
# 2802  5823          Tsu  2004   12.0  26.0   0.0    58.0   53.4         30.0
# 1127  4007          Tsu  1952   11.0   4.0  16.0    58.0   27.9         22.0
# 3141  8872          Tsu  2010    2.0  27.0   6.0    34.0   11.5         23.0
# 473   3202          Tsu  1922   11.0  11.0   4.0    32.0     36         35.0
# 1442  4337          Tsu  1965    2.0   4.0   5.0     1.0   21.6         36.0
# 1081  3950          Tsu  1950    8.0  15.0  14.0     9.0     30         33.0
# 1227  4116          Tsu  1957    3.0   9.0  14.0    22.0   31.9         33.0
#
#       EQ_PRIMARY               ...                 TOTAL_MISSING  \
# 1311         9.5               ...                           NaN
# 1423         9.2               ...                           NaN
# 3201         9.1               ...                           NaN
# 2802         9.1               ...                           NaN
# 1127         9.0               ...                           NaN
# 3141         8.8               ...                           NaN
# 473          8.7               ...                           NaN
# 1442         8.7               ...                           NaN
# 1081         8.6               ...                           NaN
# 1227         8.6               ...                           NaN
#
#       TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  TOTAL_INJURIES_DESCRIPTION  \
# 1311                        NaN          3000.0                         4.0
# 1423                        NaN             NaN                         NaN
# 3201                        NaN          6152.0                         4.0
# 2802                        NaN             NaN                         3.0
# 1127                        NaN             NaN                         NaN
# 3141                        NaN         12000.0                         4.0
# 473                         NaN             NaN                         NaN
# 1442                        NaN             NaN                         NaN
# 1081                        NaN             NaN                         NaN
# 1227                        NaN             1.0                         1.0
#
#       TOTAL_DAMAGE_MILLIONS_DOLLARS  TOTAL_DAMAGE_DESCRIPTION  \
# 1311                       1000.000                       4.0
# 1423                        400.000                       4.0
# 3201                     220085.456                       4.0
# 2802                      10000.000                       4.0
# 1127                            NaN                       3.0
# 3141                      30000.000                       4.0
# 473                             NaN                       3.0
# 1442                          0.010                       1.0
# 1081                         20.000                       3.0
# 1227                            NaN                       3.0
#
#       TOTAL_HOUSES_DESTROYED TOTAL_HOUSES_DESTROYED_DESCRIPTION  \
# 1311                 58622.0                                4.0
# 1423                     NaN                                3.0
# 3201                127511.0                                4.0
# 2802                     NaN                                3.0
# 1127                     NaN                                NaN
# 3141                     NaN                                NaN
# 473                      NaN                                3.0
# 1442                     NaN                                NaN
# 1081                     NaN                                NaN
# 1227                     NaN                                NaN
#
#      TOTAL_HOUSES_DAMAGED TOTAL_HOUSES_DAMAGED_DESCRIPTION
# 1311                  NaN                              NaN
# 1423                  NaN                              NaN
# 3201             273796.0                              4.0
# 2802                  NaN                              NaN
# 1127                  NaN                              NaN
# 3141             500000.0                              4.0
# 473                   NaN                              NaN
# 1442                  NaN                              NaN
# 1081                  NaN                              NaN
# 1227                  NaN                              NaN
#
# [10 rows x 47 columns]

# %%
#top 10 earthquakes by damage in dollars 
earthquake_damage_dollars = earthquake_df.sort_values(by='DAMAGE_MILLIONS_DOLLARS', ascending = False)
earthquake_damage_dollars.head(10)
# Out:
#        I_D FLAG_TSUNAMI  YEAR  MONTH   DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  \
# 3201  9799          Tsu  2011    3.0  11.0   5.0    46.0   24.1         30.0
# 2382  5399          Tsu  1995    1.0  16.0  20.0    46.0   52.1         22.0
# 3018  7843          Tsu  2008    5.0  12.0   6.0    28.0    1.5         19.0
# 2352  5372          Tsu  1994    1.0  17.0  12.0    30.0   55.3         18.0
# 3141  8872          Tsu  2010    2.0  27.0   6.0    34.0   11.5         23.0
# 2777  5807          NaN  2004   10.0  23.0   8.0    56.0    0.8         16.0
# 2510  5527          Tsu  1999    8.0  17.0   0.0     1.0   39.1         13.0
# 1919  4903          NaN  1980   11.0  23.0  18.0    34.0   53.8         20.0
# 2168  5184          NaN  1988   12.0   7.0   7.0    41.0   24.2          5.0
# 3273  9901          NaN  2012    5.0  29.0   7.0     0.0      3         10.0
#
#       EQ_PRIMARY               ...                 TOTAL_MISSING  \
# 3201         9.1               ...                           NaN
# 2382         6.9               ...                           NaN
# 3018         7.9               ...                           NaN
# 2352         6.7               ...                           NaN
# 3141         8.8               ...                           NaN
# 2777         6.6               ...                           NaN
# 2510         7.6               ...                           NaN
# 1919         6.9               ...                           NaN
# 2168         6.8               ...                           NaN
# 3273         5.9               ...                           NaN
#
#       TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  TOTAL_INJURIES_DESCRIPTION  \
# 3201                        NaN          6152.0                         4.0
# 2382                        NaN         36896.0                         4.0
# 3018                        NaN        374171.0                         4.0
# 2352                        NaN          7000.0                         4.0
# 3141                        NaN         12000.0                         4.0
# 2777                        NaN          3183.0                         4.0
# 2510                        NaN         50000.0                         4.0
# 1919                        NaN          7700.0                         4.0
# 2168                        NaN             NaN                         NaN
# 3273                        NaN           350.0                         3.0
#
#       TOTAL_DAMAGE_MILLIONS_DOLLARS  TOTAL_DAMAGE_DESCRIPTION  \
# 3201                     220085.456                       4.0
# 2382                     100000.000                       4.0
# 3018                      86000.000                       4.0
# 2352                      40000.000                       4.0
# 3141                      30000.000                       4.0
# 2777                      28000.000                       4.0
# 2510                      20000.000                       4.0
# 1919                      20000.000                       4.0
# 2168                      16200.000                       4.0
# 3273                      15800.000                       4.0
#
#       TOTAL_HOUSES_DESTROYED TOTAL_HOUSES_DESTROYED_DESCRIPTION  \
# 3201                127511.0                                4.0
# 2382                200000.0                                4.0
# 3018               5360000.0                                4.0
# 2352                 40000.0                                4.0
# 3141                     NaN                                NaN
# 2777                  6000.0                                4.0
# 2510                     NaN                                NaN
# 1919                     NaN                                NaN
# 2168                     NaN                                4.0
# 3273                     NaN                                NaN
#
#      TOTAL_HOUSES_DAMAGED TOTAL_HOUSES_DAMAGED_DESCRIPTION
# 3201             273796.0                              4.0
# 2382                  NaN                              NaN
# 3018           21000000.0                              4.0
# 2352                  NaN                              NaN
# 3141             500000.0                              4.0
# 2777                  NaN                              NaN
# 2510              73342.0                              4.0
# 1919                  NaN                              NaN
# 2168                  NaN                              NaN
# 3273                  NaN                              NaN
#
# [10 rows x 47 columns]

# %%
#top 10 earthquakes by death 
earthquake_most_deaths = earthquake_df.sort_values(by='DEATHS', ascending = False)
earthquake_most_deaths.head(10)
# Out:
#        I_D FLAG_TSUNAMI  YEAR  MONTH   DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  \
# 3134  8732          Tsu  2010    1.0  12.0  21.0    53.0     10         13.0
# 1783  4735          NaN  1976    7.0  27.0  19.0    42.0   54.6         23.0
# 436   3165          Tsu  1920   12.0  16.0  12.0     5.0   54.7         25.0
# 493   3227          Tsu  1923    9.0   1.0   2.0    58.0     37         35.0
# 1040  3891          NaN  1948   10.0   5.0  20.0    12.0      7         18.0
# 3018  7843          Tsu  2008    5.0  12.0   6.0    28.0    1.5         19.0
# 195   2846          Tsu  1908   12.0  28.0   4.0    20.0     27         40.0
# 2850  6778          NaN  2005   10.0   8.0   3.0    50.0   40.8         26.0
# 1608  4531          Tsu  1970    5.0  31.0  20.0    23.0   27.3         43.0
# 779   3550          Tsu  1935    5.0  30.0  21.0    32.0     46         33.0
#
#       EQ_PRIMARY               ...                 TOTAL_MISSING  \
# 3134         7.0               ...                           NaN
# 1783         7.5               ...                           NaN
# 436          8.3               ...                           NaN
# 493          7.9               ...                       43476.0
# 1040         7.3               ...                           NaN
# 3018         7.9               ...                           NaN
# 195          7.0               ...                           NaN
# 2850         7.6               ...                           NaN
# 1608         7.9               ...                           NaN
# 779          7.5               ...                           NaN
#
#       TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  TOTAL_INJURIES_DESCRIPTION  \
# 3134                        NaN        300000.0                         4.0
# 1783                        NaN        799000.0                         4.0
# 436                         NaN             NaN                         NaN
# 493                         4.0         47000.0                         4.0
# 1040                        NaN             NaN                         4.0
# 3018                        NaN        374171.0                         4.0
# 195                         NaN             NaN                         NaN
# 2850                        NaN        146599.0                         4.0
# 1608                        NaN         50000.0                         4.0
# 779                         NaN             NaN                         NaN
#
#       TOTAL_DAMAGE_MILLIONS_DOLLARS  TOTAL_DAMAGE_DESCRIPTION  \
# 3134                         8000.0                       4.0
# 1783                         5600.0                       4.0
# 436                            25.0                       4.0
# 493                           600.0                       4.0
# 1040                           25.0                       4.0
# 3018                        86000.0                       4.0
# 195                           116.0                       4.0
# 2850                         6680.0                       4.0
# 1608                          530.0                       4.0
# 779                            25.0                       4.0
#
#       TOTAL_HOUSES_DESTROYED TOTAL_HOUSES_DESTROYED_DESCRIPTION  \
# 3134                 97294.0                                4.0
# 1783                     NaN                                NaN
# 436                      NaN                                NaN
# 493                 695000.0                                4.0
# 1040                     NaN                                4.0
# 3018               5360000.0                                4.0
# 195                      NaN                                4.0
# 2850                     NaN                                3.0
# 1608                     NaN                                3.0
# 779                      NaN                                4.0
#
#      TOTAL_HOUSES_DAMAGED TOTAL_HOUSES_DAMAGED_DESCRIPTION
# 3134             188383.0                              4.0
# 1783                  NaN                              NaN
# 436                   NaN                              NaN
# 493                   NaN                              NaN
# 1040                  NaN                              NaN
# 3018           21000000.0                              4.0
# 195                   NaN                              NaN
# 2850                  NaN                              NaN
# 1608                  NaN                              NaN
# 779                   NaN                              NaN
#
# [10 rows x 47 columns]

# %%
#total death count- CHECK UNITS
total_death=earthquake_most_deaths["DEATHS"].sum()
total_death
# Out:
# 2209468.0

# %%
#top 10 years in terms of damage in dollars(millions)

total_damage_values = round(earthquake_df.groupby('YEAR')['DAMAGE_MILLIONS_DOLLARS'].sum(),2)
total_damage_in_years = total_damage_values.sort_values(ascending=False)

total_damage_in_years.head(10)
# Out:
# YEAR
# 2011    239536.40
# 1995    101787.90
# 2008     86004.00
# 2010     47173.30
# 1999     41680.28
# 1994     40420.48
# 2004     38757.00
# 1980     25500.25
# 2016     21491.00
# 2012     16883.30
# Name: DAMAGE_MILLIONS_DOLLARS, dtype: float64

# %%
#creating bins
bins = [1899, 1909, 1919, 1929, 1939, 1949, 1959, 1969, 1979, 1989, 1999, 2009, 2018]

group_names = ["1900s", "1910s", "1920s", "1930s", "1940s", "1950s", "1960s", "1970s", "1980s", "1990s", "2000s", "2010s" ]

earthquake_df["DECADE"] = pd.cut(earthquake_df["YEAR"], bins, labels=group_names)
earthquake_df.head()
# Out:
#     I_D FLAG_TSUNAMI  YEAR  MONTH   DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  \
# 0  9925          Tsu  1900    1.0  10.0   NaN     NaN    NaN          NaN
# 1  2566          NaN  1900    1.0  11.0   9.0     7.0                 NaN
# 2  2567          NaN  1900    1.0  14.0   NaN     NaN    NaN          NaN
# 3  2569          NaN  1900    1.0  20.0   6.0    33.0     30         10.0
# 4  2571          NaN  1900    5.0  16.0  20.0    12.0                60.0
#
#    EQ_PRIMARY  ...    TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  \
# 0         NaN  ...                          NaN             NaN
# 1         7.8  ...                          NaN             NaN
# 2         NaN  ...                          NaN             NaN
# 3         7.4  ...                          NaN             NaN
# 4         7.8  ...                          NaN             NaN
#
#    TOTAL_INJURIES_DESCRIPTION  TOTAL_DAMAGE_MILLIONS_DOLLARS  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
#
#    TOTAL_DAMAGE_DESCRIPTION  TOTAL_HOUSES_DESTROYED  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       2.0                     NaN
# 3                       1.0                     NaN
# 4                       NaN                     NaN
#
#    TOTAL_HOUSES_DESTROYED_DESCRIPTION TOTAL_HOUSES_DAMAGED  \
# 0                                 NaN                  NaN
# 1                                 NaN                  NaN
# 2                                 NaN                  NaN
# 3                                 NaN                  NaN
# 4                                 NaN                  NaN
#
#   TOTAL_HOUSES_DAMAGED_DESCRIPTION DECADE
# 0                              NaN  1900s
# 1                              NaN  1900s
# 2                              3.0  1900s
# 3                              NaN  1900s
# 4                              NaN  1900s
#
# [5 rows x 48 columns]

# %%
#number of earthquakes by Decade
total_earthquakes_decade=earthquake_df['DECADE'].value_counts()
total_earthquakes_decade
# Out:
# 2000s    597
# 2010s    475
# 1990s    327
# 1980s    314
# 1960s    296
# 1970s    294
# 1930s    236
# 1950s    233
# 1900s    229
# 1920s    220
# 1910s    198
# 1940s    184
# Name: DECADE, dtype: int64

# %%
#number of tsunamis from earthquakes 
tsunamis=earthquake_df['FLAG_TSUNAMI'].value_counts()
tsunamis
# Out:
# Tsu    998
# Name: FLAG_TSUNAMI, dtype: int64
